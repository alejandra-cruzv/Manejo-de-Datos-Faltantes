# %% [markdown]
# ## Configuración de ambiente de trabajo

# %% [markdown]
# ```bash
# pip install --upgrade pip
# ```

# %% [markdown]
# ```bash
# pip install pyjanitor matplotlib==3.5.1 missingno numpy pandas pyreadr seaborn session-info upsetplot==0.6.1
# ```
#
# or
#
# ```bash
# pip install -r requirements.txt
# ```

# %% [markdown]
# ## Importar librerías
#
# pyjanitor: 0.31.0
# missingno: 0.5.2
# numpy: 1.26.4
# matplotlib: 3.5.3
# pandas: 2.3.3
# pyreadr: 0.4.6
# seaborn: 0.12.2
# upsetplot: 0.6.1

# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
# !pip install pyjanitor pyreadr upsetplot missingno
# Out:
# Requirement already satisfied: pyjanitor in /usr/local/lib/python3.12/dist-packages (0.32.3)
# Requirement already satisfied: pyreadr in /usr/local/lib/python3.12/dist-packages (0.5.4)
# Requirement already satisfied: upsetplot in /usr/local/lib/python3.12/dist-packages (0.9.0)
# Requirement already satisfied: missingno in /usr/local/lib/python3.12/dist-packages (0.5.2)
# Requirement already satisfied: natsort in /usr/local/lib/python3.12/dist-packages (from pyjanitor) (8.4.0)
# Requirement already satisfied: pandas_flavor==0.8.1 in /usr/local/lib/python3.12/dist-packages (from pyjanitor) (0.8.1)
# Requirement already satisfied: multipledispatch in /usr/local/lib/python3.12/dist-packages (from pyjanitor) (1.0.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from pyjanitor) (1.16.3)
# Requirement already satisfied: pandas>=0.23 in /usr/local/lib/python3.12/dist-packages (from pandas_flavor==0.8.1->pyjanitor) (2.2.2)
# Requirement already satisfied: xarray in /usr/local/lib/python3.12/dist-packages (from pandas_flavor==0.8.1->pyjanitor) (2025.12.0)
# Requirement already satisfied: matplotlib>=2.0 in /usr/local/lib/python3.12/dist-packages (from upsetplot) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from missingno) (2.0.2)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (from missingno) (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0->upsetplot) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0->upsetplot) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0->upsetplot) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0->upsetplot) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0->upsetplot) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0->upsetplot) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0->upsetplot) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0->upsetplot) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.23->pandas_flavor==0.8.1->pyjanitor) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.23->pandas_flavor==0.8.1->pyjanitor) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=2.0->upsetplot) (1.17.0)

# %%
# !pip install session-info
# Out:
# Requirement already satisfied: session-info in /usr/local/lib/python3.12/dist-packages (1.0.1)
# Requirement already satisfied: stdlib_list in /usr/local/lib/python3.12/dist-packages (from session-info) (0.12.0)

# %%
import janitor
import matplotlib.pyplot as plt
import missingno
import numpy as np
import pandas as pd
import pyreadr
import seaborn as sns
import session_info
import upsetplot
import matplotlib

# %% [markdown]
# ## Importar funciones personalizadas

# %% [markdown]
# ## Configurar el aspecto general de las gráficas del proyecto

# %%
# %matplotlib inline

sns.set(
    rc={
        "figure.figsize": (10, 10)
    }
)

sns.set_style("whitegrid")

# %% [markdown]
# ## Operar con valores faltantes

# %% [markdown]
# ### Python

# %%
print(
None or True,
    None or False,
    None == None,
    None is None,
    #None + True,
    #None /False
    type(None)
)
# Out:
# True False True True <class 'NoneType'>

# %% [markdown]
# ### NumPy

# %%
print(
    np.nan or True,
    np.nan ==np.nan,
    np.nan is np.nan,
    np.nan / 2,
    np.isnan(np.nan)

)
# Out:
# nan False True nan True

# %% [markdown]
# ### Pandas

# %%
test_missing_df = pd.DataFrame.from_dict(
    data=dict(
        x=[0,1,np.nan, np.nan, None],
        y=[0, 1, pd.NA, np.nan, None]
    )
)

test_missing_df
# Out:
#      x     y
# 0  0.0     0
# 1  1.0     1
# 2  NaN  <NA>
# 3  NaN   NaN
# 4  NaN  None

# %% [markdown]
# Vemos que tenemos varios datos con NaN, None, etc. Esto es porque pandas es actualizado constantemente, y tiene varias formas de representar los valores faltantes.

# %%
test_missing_df.isna()
# Out:
#        x      y
# 0  False  False
# 1  False  False
# 2   True   True
# 3   True   True
# 4   True   True

# %%
test_missing_df.x.isnull()
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4     True
# Name: x, dtype: bool

# %%
#Creamos una serie
#dtype: float64
pd.Series([1, np.nan])
# Out:
# 0    1.0
# 1    NaN
# dtype: float64

# %%
#dtype: datetime64[ns]
pd.Series([pd.to_datetime("2022-01-01"), np.nan])
# Out:
# 0   2022-01-01
# 1          NaT
# dtype: datetime64[ns]

# %%
#Creamos una serie de -1 caracteres. Pandas no lo detecta como valores nulos, esto debido a que pandas a veces simboliza a los valores nulos como '-1'
pd.Series([-1]).isnull()
# Out:
# 0    False
# dtype: bool

# %% [markdown]
# ## Cargar los conjuntos de datos

# %% [markdown]
# ### Pima Indians Diabetes

# %%
#Leer el archivo

url="https://raw.githubusercontent.com/alejandra-cruzv/Manejo-de-Datos-Faltantes/refs/heads/master/data/pima-indians-diabetes.csv"

#Convertir el archivo csv en un DataFrame con pandas
data_df=pd.read_csv(url, names = ['pregnancies', 'glucose', 'blood_presure', 'skin_thickness', 'insulin', 'bmi', 'diabetes_pedigree_function','age', 'outcome'])
data_df.head()
# Out:
#    pregnancies  glucose  blood_presure  skin_thickness  insulin   bmi  \
# 0            6      148             72              35        0  33.6
# 1            1       85             66              29        0  26.6
# 2            8      183             64               0        0  23.3
# 3            1       89             66              23       94  28.1
# 4            0      137             40              35      168  43.1
#
#    diabetes_pedigree_function  age  outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1

# %% [markdown]
# ### naniar (oceanbuoys, pedestrian, riskfactors)
#
# Estos conjuntos de datos tienen formato .rda (R).
# Para poder utilizarlos, debemos convertirlos:

# %% [markdown]
# #### Para Linux o Mac, podemos hacer más fácil el proceso 'automatizando':
# #### Crear unidades de información de los conjuntos de datos (los 3 anteriores)

# %% [markdown]
# base_url = 'https://github.com/ubicación...'
# datasets_names = ('nombre1', 'nombre2', 'nombre3')
# extension = ".rda"
#
# #Descargar y cargar los conjuntos de datos
#
# datasets_dfs = {}
#
# for dataset_name in datasets_names:
#     dataset_file = f"{ dataset_name }{ extension }"
#     dataset_output_file = f"./data/{ dataset_file }"
#     dataset_url = f"{base_url}{dataset_file}"
#
#     !wget -q -O { dataset_output_file } {dataset_url}
#     datasets_dfs[f"{dataset_name}_df"] = pyread.read_r(dataset_output_file).get(dataset_name)
#
# datasets_dfs.keys()

# %%
# !wget https://raw.githubusercontent.com/alejandra-cruzv/Manejo-de-Datos-Faltantes/master/data/oceanbuoys.rda
# !wget https://raw.githubusercontent.com/alejandra-cruzv/Manejo-de-Datos-Faltantes/master/data/pedestrian.rda
# !wget https://raw.githubusercontent.com/alejandra-cruzv/Manejo-de-Datos-Faltantes/master/data/riskfactors.rda
# Out:
# --2025-12-16 23:54:45--  https://raw.githubusercontent.com/alejandra-cruzv/Manejo-de-Datos-Faltantes/master/data/oceanbuoys.rda
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5594 (5.5K) [application/octet-stream]
# Saving to: ‘oceanbuoys.rda.2’
#
# oceanbuoys.rda.2    100%[===================>]   5.46K  --.-KB/s    in 0s
#
# 2025-12-16 23:54:45 (50.7 MB/s) - ‘oceanbuoys.rda.2’ saved [5594/5594]
#
# --2025-12-16 23:54:46--  https://raw.githubusercontent.com/alejandra-cruzv/Manejo-de-Datos-Faltantes/master/data/pedestrian.rda
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 60244 (59K) [application/octet-stream]
# Saving to: ‘pedestrian.rda’
#
# pedestrian.rda      100%[===================>]  58.83K  --.-KB/s    in 0.009s
#
# 2025-12-16 23:54:46 (6.30 MB/s) - ‘pedestrian.rda’ saved [60244/60244]
#
# --2025-12-16 23:54:46--  https://raw.githubusercontent.com/alejandra-cruzv/Manejo-de-Datos-Faltantes/master/data/riskfactors.rda
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6026 (5.9K) [application/octet-stream]
# Saving to: ‘riskfactors.rda’
#
# riskfactors.rda     100%[===================>]   5.88K  --.-KB/s    in 0s
#
# 2025-12-16 23:54:46 (45.9 MB/s) - ‘riskfactors.rda’ saved [6026/6026]

# %%
oceanbuoys = pyreadr.read_r('oceanbuoys.rda.2')

pedestrian = pyreadr.read_r('pedestrian.rda')

riskfactors = pyreadr.read_r('riskfactors.rda')

# %% [markdown]
# #### Para Windows:
#
# #Leer los archivos
# import pyreadr
#
#
# #Aquí data_path es una cadena de texto
# oceanbuoys_url= "https://raw.githubusercontent.com/alejandra-cruzv/Manejo-de-Datos-Faltantes/master/data/oceanbuoys.rda"
#
# pedestrian_url= "https://github.com/alejandra-cruzv/Manejo-de-Datos-Faltantes/blob/master/data/pedestrian.rda"
#
# riskfactors_url= "https://github.com/alejandra-cruzv/Manejo-de-Datos-Faltantes/blob/master/data/riskfactors.rda"
#
#
# # Cargar los tres archivos
# oceanbuoys = pyreadr.read_r(oceanbuoys_url)
#
# pedestrian = pyreadr.read_r(pedestrian_url)
#
# riskfactors = pyreadr.read_r(riskfactors_url)
#
# # Extraer los dataframes (es similar a hacer la conversión de data=pd.read_csv())
#
# print(oceanbuoys.keys())  # muestra los nombres de los objetos guardados
#
# print(pedestrian.keys())  # muestra los nombres de los objetos guardados
#
# print(riskfactors.keys())  # muestra los nombres de los objetos guardados
#
# #Definir los 3 Dataframes
#
# oceanbuoys = oceanbuoys['oceanbuoys']
# pedestrian = pedestrian['pedestrian']
# riskfactors = riskfactors['riskfactors']
#
# #Ahora podemos trabajar con ellos como cualquier otro Data Frame en Python
#
# oceanbuoys.shape, pedestrian.shape, riskfactors.shape, data_df.shape
#
# Vemos la información de uno de nuestros conjuntos de datos
# riskfactors.info()
#
# Podemos notar que hay muchos valores faltantes, vamos a trabajar con ellos.

# %% [markdown]
# ## Tabulación de valores faltantes

# %% [markdown]
# ### Resúmenes básicos de valores faltantes

# %% [markdown]
# #### Número total de valores completos (sin observaciones faltantes)

# %% [markdown]
# #### Número total de valores faltantes

# %% [markdown]
# ### Resúmenes tabulares de valores faltantes

# %% [markdown]
# #### Variables / Columnas

# %% [markdown]
# ##### Resumen por variable

# %% [markdown]
# ###### Tabulación del resumen por variable

# %% [markdown]
# #### Casos / Observaciones / Filas

# %% [markdown]
# ##### Resúmenes por caso

# %% [markdown]
# ###### Tabulación del resumen por caso

# %% [markdown]
# ### Intervalos de valores faltantes

# %% [markdown]
# ### _Run length_ de valores faltantes

# %% [markdown]
# ## Visualización inicial de valores faltantes

# %% [markdown]
# ### Variable

# %% [markdown]
# ### Casos / Observaciones / Filas

# %% [markdown]
# ## Codificación de valores faltantes

# %% [markdown]
# <div class="alert alert-warning", role="alert">
#     <b style="font-size: 1.5em;">🚧 Advertencia</b>
#     <p>
#     Al igual que cada persona es una nueva puerta a un mundo diferente, los <b>valores faltantes</b> existen en diferentes formas y colores. Al trabajar con valores faltantes será crítico entender sus distintas representaciones. A pesar de que el conjunto de datos de trabajo pareciera que no contiene valores faltantes, deberás ser capaz de ir más allá de lo observado a simple vista para remover el manto tras el cual se esconde lo desconocido.
#     </p>
# </div>

# %% [markdown]
# ### Valores comúnmente asociados a valores faltantes

# %% [markdown]
# #### Cadenas de texto

# %%
common_na_strings = (
    "missing",
    "NA",
    "N A",
    "N/A",
    "#N/A",
    "NA ",
    " NA",
    "N /A",
    "N / A",
    " N / A",
    "N / A ",
    "na",
    "n a",
    "n/a",
    "na ",
    " na",
    "n /a",
    "n / a",
    " a / a",
    "n / a ",
    "NULL",
    "null",
    "",
    "?",
    "*",
    ".",
)

# %% [markdown]
# #### Números

# %%
common_na_numbers = (-9, -99, -999, -9999, 9999, 66, 77, 88, -1)

# %% [markdown]
# ### ¿Cómo encontrar los valores comúnmente asociados a valores faltantes?

# %%
missing_data_example_df = pd.DataFrame.from_dict(
    dict(
        x = [1, 3, "NA", -99, -98, -99],
        y = ["A", "N/A", "NA", "E", "F", "G"],
        z = [-100, -99, -98, -101, -1, -1]
    )
)

missing_data_example_df

# %% [markdown]
# #### Revisar tipos de datos

# %% [markdown]
# #### Revisar valores únicos de los datos

# %% [markdown]
# ### Sustituyendo valores comúnmente asociados a valores faltantes

# %% [markdown]
# #### Sustitución desde la lectura de datos

# %% [markdown]
# #### Sustitución global

# %% [markdown]
# #### Sustitución dirigida

# %% [markdown]
# ## Conversión de valores faltantes implícitos a explícitos

# %% [markdown]
# <div class="alert alert-warning", role="alert">
#     <b style="font-size: 1.5em;">🚧 Advertencia</b>
#     <br>
#     <br>
#     <p>
#         <i>
#         "<b>Implícito</b> se refiere a todo aquello que se entiende que está incluido
#         pero sin ser expresado de forma directa o explícitamente."
#         </i>
#     </p>
#     <p>
#     Un <code>valor faltante implícito</code> indica que el valor faltante <b>debería estar incluido</b>
#     en el conjunto de datos del análisis, <b>sin que éste lo diga</b> o lo <b>especifique</b>.
#     Por lo general, son valores que podemos encontrar al pivotar nuestros datos
#     o contabilizar el número de apariciones de combinaciones de las variables de estudio.
#     </p>
# </div>

# %%
implicit_to_explicit_df = pd.DataFrame.from_dict(
    data={
        "name": ["lynn", "lynn", "lynn", "zelda"],
        "time": ["morning", "afternoon", "night", "morning"],
        "value": [350, 310, np.nan, 320]
    }
)

implicit_to_explicit_df

# %% [markdown]
# ### Estrategias para la identificación de valores faltantes implícitos

# %% [markdown]
# #### Pivotar la tabla de datos

# %% [markdown]
# #### Cuantificar ocurrencias de n-tuplas

# %% [markdown]
# ### Exponer filas faltantes implícitas a explícitas

# %% [markdown]
# <div class="alert alert-info">
#     <b style="font-size: 1.5em;">📘 Información</b>
#     <p>
#        <a href="https://pyjanitor-devs.github.io/pyjanitor/api/functions/#janitor.functions.complete.complete", class="alert-link"><code>janitor.complete()</code></a> está modelada a partir de la función <a href="https://tidyr.tidyverse.org/reference/complete.html", class="alert-link"><code>complete()</code></a> del paquete <a href="https://tidyr.tidyverse.org/index.html", class="alert-link"><code>tidyr</code></a> y es un <i>wrapper</i> alrededor de <a href="https://pyjanitordevs.github.io/pyjanitor/api/functions/#janitor.functions.expand_grid.expand_grid", class="alert-link"><code>janitor.expand_grid()</code></a>, <a href="https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.merge.html", class="alert-link"><code>pd.merge()</code></a> y <a href="https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.merge.html", class="alert-link"><code>pd.fillna()</code></a>. En cierto modo, es lo contrario de <a href="https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dropna.html", class="alert-link"><code>pd.dropna()</code></a>, ya que expone implícitamente las filas que faltan.
#     </p>
#     <p>
#     Son posibles combinaciones de nombres de columnas o una lista/tupla de nombres de columnas, o incluso un  diccionario de nombres de columna y nuevos valores.
#     </p>
#     <p>
#     Las columnas <a href="https://pandas.pydata.org/docs/user_guide/advanced.html"><code>MultiIndex</code></a> no son complatibles.
#     </p>
# </div>

# %% [markdown]
# #### Exponer n-tuplas de valores faltantes
#
# Ejemplo, encontrar los pares faltantes de `name` y `time`.

# %% [markdown]
# #### Limitar la exposición de n-tuplas de valores faltantes

# %% [markdown]
# #### Rellenar los valores faltantes

# %% [markdown]
# #### Limitar el rellenado de valores faltantes implícitos

# %% [markdown]
# ## Tipos de valores faltantes

# %% [markdown]
# ### _Missing Completely At Random_ (MCAR)

# %% [markdown]
# ### _Missing At Random_ (MAR)

# %% [markdown]
# ### _Missing Not At Random_ (MNAR)

# %% [markdown]
# ## Concepto y aplicación de la matriz de sombras (_i.e._, _shadow matrix_)

# %% [markdown]
#  ### Construcción de la matriz de sombras

# %% [markdown]
# ### Utilizar función de utilería `bind_shadow_matrix()`

# %% [markdown]
# ### Explorar estadísticos utilizando las nuevas columnas de la matriz de sombras

# %% [markdown]
# ## Visualización de valores faltantes en una variable

# %% [markdown]
# ## Visualización de valores faltantes en dos variables

# %% [markdown]
# ## Correlación de nulidad

# %% [markdown]
# ## Eliminación de valores faltantes

# %% [markdown]
# <div class="alert alert-warning", role="alert">
#     <b style="font-size: 1.5em;">🚧 Advertencia</b>
#     <p>
#     La eliminación de valores faltantes <b>asume</b> que los valores faltantes están perdidos
#     completamente al azar (<code>MCAR</code>). En cualquier otro caso, realizar una
#     eliminación de valores faltantes podrá ocasionar <b>sesgos</b> en los
#     análisis y modelos subsecuentes.
#     </p>
# </div>

# %% [markdown]
# Primero observa el número total de observaciones y variables que tiene tu conjunto de datos.

# %% [markdown]
# ### _Pairwise deletion_ (eliminación por pares)

# %% [markdown]
# ### _Listwise Deletion or Complete Case_ (Eliminación por lista o caso completo)

# %% [markdown]
# #### Con base en 1 columna

# %% [markdown]
# #### Con base en 2 o más columnas

# %% [markdown]
# ### Representación gráfica tras la eliminación de los valores faltantes

# %% [markdown]
# ## Imputación básica de valores faltantes

# %% [markdown]
# ### Imputación con base en el contexto

# %%
implicit_to_explicit_df = pd.DataFrame(
    data={
        "name": ["lynn", np.nan, "zelda", np.nan, "shadowsong", np.nan],
        "time": ["morning", "afternoon", "morning", "afternoon", "morning", "afternoon",],
        "value": [350, 310, 320, 350, 310, 320]
    }
)

implicit_to_explicit_df

# %% [markdown]
# ### Imputación de un único valor

# %% [markdown]
# ## Continúa aprendiendo sobre el manejo de valores faltantes

# %% [markdown]
# <div class="alert alert-success">
#     <b style="font-size: 1.5em;">✅ ¡Felicidades por terminar el curso!</b>
#     <p>
# Has aprendido bastante sobre la exploración y manipulación de valores faltantes.
#     </p>
#     <p>
# Empezaste conociento las principales operaciones al trabajar con valores faltantes. Ahora, eres consciente de que estas operaciones no son universales y cada software decide tratar a los valores faltantes a su conveniencia.
#     </p>
#     <p>
# Y, hablando de conveniencias, comenzaste tu camino en la exploración de valores faltantes a través de una representación universal de qué es lo que faltaba. No obstante, no pasó mucho para darte cuenta de que los valores faltantes pueden existir en formas muy variables. Incluso, en formas en las que no sabemos que nos faltan estos valores en sí mismos.
#     </p>
#     <p>
# Con los valores faltantes ya expuestos, te conviertes en una persona capaz de explorarlos en profundidad de forma estadística y visual. Entendiendo así, los distintos mecanismos que pueden tener los valores faltantes: MCAR, MAR y MNAR.
#     </p>
#     <p>
# A su vez, aprendiste las bases sobre cómo tratarlos a través de la eliminación de elementos o la imputación de valores de una forma básica y sencilla. Por lo tanto, necesitarás continuar tu camino de aprendizaje con un curso que te permita profundizar en estas técnicas de tratamiento para valores faltantes.
#     </p>
#     <p>
# Te recomiendo continuar con mi <a href="https://platzi.com/cursos/datos-faltantes-imputacion/">Curso de Manejo de Datos Faltantes: Imputación</a>. Estoy seguro de que tus habilidades adquiridas hasta el momento mejorarán, permitiéndote realizar análisis cada vez más complejos y cercanos al mundo real.
#     </p>
#     <p>
#     Con mucha alegría por tu logro,
#    Jesús Vélez Santiago
#     </p>
#
# </div>

# %% [markdown]
# ## Información de sesión

# %%
session_info.show()

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=694a3d08-7f18-421d-9e2f-c2820a79680e' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
